# %%
# !pip install ultralytics
# Out:
# Requirement already satisfied: ultralytics in c:\users\dell\appdata\local\programs\python\python313\lib\site-packages (8.3.78)
# Requirement already satisfied: numpy<=2.1.1,>=1.23.0 in c:\users\dell\appdata\local\programs\python\python313\lib\site-packages (from ultralytics) (2.1.1)
# Requirement already satisfied: matplotlib>=3.3.0 in c:\users\dell\appdata\local\programs\python\python313\lib\site-packages (from ultralytics) (3.10.0)
# Requirement already satisfied: opencv-python>=4.6.0 in c:\users\dell\appdata\local\programs\python\python313\lib\site-packages (from ultralytics) (4.11.0.86)
# Requirement already satisfied: pillow>=7.1.2 in c:\users\dell\appdata\local\programs\python\python313\lib\site-packages (from ultralytics) (11.1.0)
# Requirement already satisfied: pyyaml>=5.3.1 in c:\users\dell\appdata\local\programs\python\python313\lib\site-packages (from ultralytics) (6.0.2)
# Requirement already satisfied: requests>=2.23.0 in c:\users\dell\appdata\local\programs\python\python313\lib\site-packages (from ultralytics) (2.32.3)
# Requirement already satisfied: scipy>=1.4.1 in c:\users\dell\appdata\local\programs\python\python313\lib\site-packages (from ultralytics) (1.15.2)
# Requirement already satisfied: torch>=1.8.0 in c:\users\dell\appdata\local\programs\python\python313\lib\site-packages (from ultralytics) (2.6.0)
# Requirement already satisfied: torchvision>=0.9.0 in c:\users\dell\appdata\local\programs\python\python313\lib\site-packages (from ultralytics) (0.21.0)
# Requirement already satisfied: tqdm>=4.64.0 in c:\users\dell\appdata\local\programs\python\python313\lib\site-packages (from ultralytics) (4.67.1)
# Requirement already satisfied: psutil in c:\users\dell\appdata\local\programs\python\python313\lib\site-packages (from ultralytics) (7.0.0)
# Requirement already satisfied: py-cpuinfo in c:\users\dell\appdata\local\programs\python\python313\lib\site-packages (from ultralytics) (9.0.0)
# Requirement already satisfied: pandas>=1.1.4 in c:\users\dell\appdata\local\programs\python\python313\lib\site-packages (from ultralytics) (2.2.3)
# Requirement already satisfied: seaborn>=0.11.0 in c:\users\dell\appdata\local\programs\python\python313\lib\site-packages (from ultralytics) (0.13.2)
# Requirement already satisfied: ultralytics-thop>=2.0.0 in c:\users\dell\appdata\local\programs\python\python313\lib\site-packages (from ultralytics) (2.0.14)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\dell\appdata\local\programs\python\python313\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\dell\appdata\local\programs\python\python313\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\dell\appdata\local\programs\python\python313\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\dell\appdata\local\programs\python\python313\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in c:\users\dell\appdata\local\programs\python\python313\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\dell\appdata\local\programs\python\python313\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\dell\appdata\local\programs\python\python313\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\dell\appdata\local\programs\python\python313\lib\site-packages (from pandas>=1.1.4->ultralytics) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\dell\appdata\local\programs\python\python313\lib\site-packages (from pandas>=1.1.4->ultralytics) (2025.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\dell\appdata\local\programs\python\python313\lib\site-packages (from requests>=2.23.0->ultralytics) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\dell\appdata\local\programs\python\python313\lib\site-packages (from requests>=2.23.0->ultralytics) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\dell\appdata\local\programs\python\python313\lib\site-packages (from requests>=2.23.0->ultralytics) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\dell\appdata\local\programs\python\python313\lib\site-packages (from requests>=2.23.0->ultralytics) (2025.1.31)
# Requirement already satisfied: filelock in c:\users\dell\appdata\local\programs\python\python313\lib\site-packages (from torch>=1.8.0->ultralytics) (3.17.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in c:\users\dell\appdata\local\programs\python\python313\lib\site-packages (from torch>=1.8.0->ultralytics) (4.12.2)
# Requirement already satisfied: networkx in c:\users\dell\appdata\local\programs\python\python313\lib\site-packages (from torch>=1.8.0->ultralytics) (3.4.2)
# Requirement already satisfied: jinja2 in c:\users\dell\appdata\local\programs\python\python313\lib\site-packages (from torch>=1.8.0->ultralytics) (3.1.5)
# Requirement already satisfied: fsspec in c:\users\dell\appdata\local\programs\python\python313\lib\site-packages (from torch>=1.8.0->ultralytics) (2025.2.0)
# Requirement already satisfied: setuptools in c:\users\dell\appdata\local\programs\python\python313\lib\site-packages (from torch>=1.8.0->ultralytics) (75.8.0)
# Requirement already satisfied: sympy==1.13.1 in c:\users\dell\appdata\local\programs\python\python313\lib\site-packages (from torch>=1.8.0->ultralytics) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\dell\appdata\local\programs\python\python313\lib\site-packages (from sympy==1.13.1->torch>=1.8.0->ultralytics) (1.3.0)
# Requirement already satisfied: colorama in c:\users\dell\appdata\local\programs\python\python313\lib\site-packages (from tqdm>=4.64.0->ultralytics) (0.4.6)
# Requirement already satisfied: six>=1.5 in c:\users\dell\appdata\local\programs\python\python313\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\dell\appdata\local\programs\python\python313\lib\site-packages (from jinja2->torch>=1.8.0->ultralytics) (3.0.2)

# %%
import ultralytics
ultralytics.__version__

# %%
import cv2
import os
import pandas as pd
from ultralytics import YOLO
from tracker import Tracker
import time
import pickle

# Get the video file path from the user
video_path = input("Enter the path to the video file: ")

# Check if the file exists
if not os.path.exists(video_path):
    print("The specified video file does not exist. Please check the path.")
    exit()

# Load YOLO model
model = YOLO('yolov8s.pt')

# Open video file
cap = cv2.VideoCapture(video_path)

# Define class list for YOLO
class_list = ['person', 'bicycle', 'car', 'motorcycle', 'airplane', 'bus', 'train', 'truck', 'boat', 
              'traffic light', 'fire hydrant', 'stop sign', 'parking meter', 'bench', 'bird', 'cat', 'dog', 
              'horse', 'sheep', 'cow', 'elephant', 'bear', 'zebra', 'giraffe', 'backpack', 'umbrella', 'handbag', 
              'tie', 'suitcase', 'frisbee', 'skis', 'snowboard', 'sports ball', 'kite', 'baseball bat', 'baseball glove', 
              'skateboard', 'surfboard', 'tennis racket', 'bottle', 'wine glass', 'cup', 'fork', 'knife', 'spoon', 
              'bowl', 'banana', 'apple', 'sandwich', 'orange', 'broccoli', 'carrot', 'hot dog', 'pizza', 'donut', 
              'cake', 'chair', 'couch', 'potted plant', 'bed', 'dining table', 'toilet', 'tv', 'laptop', 'mouse', 
              'remote', 'keyboard', 'cell phone', 'microwave', 'oven', 'toaster', 'sink', 'refrigerator', 'book', 
              'clock', 'vase', 'scissors', 'teddy bear', 'hair drier', 'toothbrush']

# Initialize counters and trackers (Reset previous data)
count = 0
tracker = Tracker()
down = {}
up = {}
counter_down = []
counter_up = []

# Define line positions
red_line_y = 198
blue_line_y = 268
offset = 6

# Create folder for saving frames
if not os.path.exists('detected_frames'):
    os.makedirs('detected_frames')

# Video output setup
fourcc = cv2.VideoWriter_fourcc(*'XVID')
output_video_path = 'output.avi'
out = cv2.VideoWriter(output_video_path, fourcc, 20.0, (1020, 500))

# Get video frame rate
frame_rate = cap.get(cv2.CAP_PROP_FPS)

# Adjust the distance in meters for the lines
real_distance_meters = 50  # Distance between the two lines in meters (adjust as necessary)

while True:
    ret, frame = cap.read()
    if not ret:
        break
    count += 1
    frame = cv2.resize(frame, (1020, 500))

    results = model.predict(frame)
    a = results[0].boxes.data
    a = a.detach().cpu().numpy()
    px = pd.DataFrame(a).astype("float")
    list = []

    for index, row in px.iterrows():
        x1 = int(row[0])
        y1 = int(row[1])
        x2 = int(row[2])
        y2 = int(row[3])
        d = int(row[5])
        c = class_list[d]
        # Track car, truck, motorcycle, and bus
        if 'car' in c or 'truck' in c or 'motorcycle' in c or 'bus' in c:
            list.append([x1, y1, x2, y2])
    bbox_id = tracker.update(list)

    for bbox in bbox_id:
        x3, y3, x4, y4, id = bbox
        cx = int(x3 + x4) // 2
        cy = int(y3 + y4) // 2

        # Check if the vehicle crosses the red line (going down)
        if red_line_y < (cy + offset) and red_line_y > (cy - offset):
            down[id] = time.time()   # current time when vehicle touches the first line
        
        if id in down:
            if blue_line_y < (cy + offset) and blue_line_y > (cy - offset):
                elapsed_time = time.time() - down[id]  # time from red to blue line
                if counter_down.count(id) == 0:
                    counter_down.append(id)

                    # Convert pixel distance to real-world distance using real_distance_meters
                    pixel_distance = abs(blue_line_y - red_line_y)
                    scale_factor = real_distance_meters / pixel_distance  # meters per pixel

                    # Calculate real-world speed (in m/s) and convert to km/h
                    real_distance_travelled = pixel_distance * scale_factor
                    a_speed_ms = real_distance_travelled / elapsed_time  # meters per second
                    a_speed_kh = a_speed_ms * 3.6  # Convert to km/h

                    cv2.circle(frame, (cx, cy), 4, (0, 0, 255), -1)
                    cv2.rectangle(frame, (x3, y3), (x4, y4), (0, 255, 0), 2)  # Draw bounding box
                    cv2.putText(frame, str(id), (x3, y3), cv2.FONT_HERSHEY_COMPLEX, 0.6, (255, 255, 255), 1)
                    cv2.putText(frame, str(int(a_speed_kh)) + 'Km/h', (x4, y4), cv2.FONT_HERSHEY_COMPLEX, 0.8, (0, 255, 255), 2)

        # Check for vehicle going up
        if blue_line_y < (cy + offset) and blue_line_y > (cy - offset):
            up[id] = time.time()
        
        if id in up:
            if red_line_y < (cy + offset) and red_line_y > (cy - offset):
                elapsed1_time = time.time() - up[id]
                if counter_up.count(id) == 0:
                    counter_up.append(id)

                    # Convert pixel distance to real-world distance using real_distance_meters
                    pixel_distance1 = abs(red_line_y - blue_line_y)
                    scale_factor1 = real_distance_meters / pixel_distance1  # meters per pixel

                    # Calculate real-world speed (in m/s) and convert to km/h
                    real_distance_travelled1 = pixel_distance1 * scale_factor1
                    a_speed_ms1 = real_distance_travelled1 / elapsed1_time  # meters per second
                    a_speed_kh1 = a_speed_ms1 * 3.6  # Convert to km/h

                    cv2.circle(frame, (cx, cy), 4, (0, 0, 255), -1)
                    cv2.rectangle(frame, (x3, y3), (x4, y4), (0, 255, 0), 2)
                    cv2.putText(frame, str(id), (x3, y3), cv2.FONT_HERSHEY_COMPLEX, 0.6, (255, 255, 255), 1)
                    cv2.putText(frame, str(int(a_speed_kh1)) + 'Km/h', (x4, y4), cv2.FONT_HERSHEY_COMPLEX, 0.8, (0, 255, 255), 2)

    # Text and line colors
    text_color = (0, 0, 0)  # Black color for text
    yellow_color = (0, 255, 255)  # Yellow color for background
    red_color = (0, 0, 255)  # Red color for lines
    blue_color = (255, 0, 0)  # Blue color for lines

    # Draw the frame and lines
    cv2.rectangle(frame, (0, 0), (250, 90), yellow_color, -1)
    cv2.line(frame, (172, 198), (774, 198), red_color, 2)
    cv2.putText(frame, ('Red Line'), (172, 198), cv2.FONT_HERSHEY_SIMPLEX, 0.5, text_color, 1, cv2.LINE_AA)

    cv2.line(frame, (8, 268), (927, 268), blue_color, 2)
    cv2.putText(frame, ('Blue Line'), (8, 268), cv2.FONT_HERSHEY_SIMPLEX, 0.5, text_color, 1, cv2.LINE_AA)

    # Display the counts of vehicles going down and up
    cv2.putText(frame, ('Going Down - ' + str(len(counter_down))), (10, 30), cv2.FONT_HERSHEY_SIMPLEX, 0.5, text_color, 1, cv2.LINE_AA)
    cv2.putText(frame, ('Going Up - ' + str(len(counter_up))), (10, 60), cv2.FONT_HERSHEY_SIMPLEX, 0.5, text_color, 1, cv2.LINE_AA)
    
    # Calculate total vehicles (sum of up and down)
    total_vehicles = len(counter_up) + len(counter_down)
    
    # Display the total vehicle count
    cv2.putText(frame, ('Total Vehicles - ' + str(total_vehicles)), (10, 90), cv2.FONT_HERSHEY_SIMPLEX, 0.5, text_color, 1, cv2.LINE_AA)

    # Save frame to disk
    frame_filename = f'detected_frames/frame_{count}.jpg'
    cv2.imwrite(frame_filename, frame)

    # Write frame to output video
    out.write(frame)

    # Show the frame
    cv2.imshow("frames", frame)
    
    if cv2.waitKey(1) & 0xFF == 27:  # Escape key to exit
        break

# Print final stats and output video path
print(f"Vehicles going down: {len(counter_down)}")
print(f"Vehicles going up: {len(counter_up)}")
print(f"Total vehicles: {len(counter_up) + len(counter_down)}")
print(f"Output video saved to: {output_video_path}")

# Save tracking data to pickle file
tracking_data = {
    'down': down,
    'up': up,
    'counter_down': counter_down,
    'counter_up': counter_up
}

with open('tracking_data.pkl', 'wb') as f:
    pickle.dump(tracking_data, f)

print("Tracking data has been saved to 'tracking_data.pkl'")

# Release resources
cap.release()
out.release()
cv2.destroyAllWindows()
# Out:
# Enter the path to the video file:  highway_mini.mp4
# 0: 320x640 9 cars, 3 trucks, 299.5ms
# Speed: 11.6ms preprocess, 299.5ms inference, 1.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 2 trucks, 196.4ms
# Speed: 2.5ms preprocess, 196.4ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 2 trucks, 175.6ms
# Speed: 2.1ms preprocess, 175.6ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 2 trucks, 172.8ms
# Speed: 3.1ms preprocess, 172.8ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 2 trucks, 199.6ms
# Speed: 1.9ms preprocess, 199.6ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 2 trucks, 171.7ms
# Speed: 2.3ms preprocess, 171.7ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 2 trucks, 196.8ms
# Speed: 2.3ms preprocess, 196.8ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 2 trucks, 188.1ms
# Speed: 2.7ms preprocess, 188.1ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 2 trucks, 116.1ms
# Speed: 2.6ms preprocess, 116.1ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 2 trucks, 90.4ms
# Speed: 1.2ms preprocess, 90.4ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 2 trucks, 88.6ms
# Speed: 1.1ms preprocess, 88.6ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 2 trucks, 105.4ms
# Speed: 1.3ms preprocess, 105.4ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 2 trucks, 102.1ms
# Speed: 2.4ms preprocess, 102.1ms inference, 0.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 2 trucks, 91.8ms
# Speed: 1.2ms preprocess, 91.8ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 2 trucks, 105.3ms
# Speed: 1.4ms preprocess, 105.3ms inference, 0.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 2 trucks, 111.1ms
# Speed: 1.4ms preprocess, 111.1ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 2 trucks, 94.8ms
# Speed: 1.7ms preprocess, 94.8ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 8 cars, 2 trucks, 113.6ms
# Speed: 1.6ms preprocess, 113.6ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 8 cars, 3 trucks, 93.4ms
# Speed: 1.3ms preprocess, 93.4ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 8 cars, 2 trucks, 92.2ms
# Speed: 1.6ms preprocess, 92.2ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 8 cars, 2 trucks, 85.1ms
# Speed: 1.2ms preprocess, 85.1ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 2 trucks, 91.1ms
# Speed: 1.5ms preprocess, 91.1ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 8 cars, 2 trucks, 100.2ms
# Speed: 1.4ms preprocess, 100.2ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 2 trucks, 93.1ms
# Speed: 1.4ms preprocess, 93.1ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 2 trucks, 87.3ms
# Speed: 1.7ms preprocess, 87.3ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 10 cars, 2 trucks, 91.3ms
# Speed: 1.4ms preprocess, 91.3ms inference, 0.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 10 cars, 2 trucks, 94.5ms
# Speed: 1.5ms preprocess, 94.5ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 10 cars, 2 trucks, 85.0ms
# Speed: 1.4ms preprocess, 85.0ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 10 cars, 2 trucks, 86.3ms
# Speed: 1.4ms preprocess, 86.3ms inference, 0.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 2 trucks, 83.6ms
# Speed: 1.2ms preprocess, 83.6ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 2 trucks, 82.9ms
# Speed: 1.1ms preprocess, 82.9ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 2 trucks, 101.7ms
# Speed: 1.5ms preprocess, 101.7ms inference, 0.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 8 cars, 3 trucks, 93.6ms
# Speed: 1.5ms preprocess, 93.6ms inference, 0.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 8 cars, 2 trucks, 104.8ms
# Speed: 1.2ms preprocess, 104.8ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 2 trucks, 115.5ms
# Speed: 1.3ms preprocess, 115.5ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 2 trucks, 105.8ms
# Speed: 1.4ms preprocess, 105.8ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 2 trucks, 92.2ms
# Speed: 1.5ms preprocess, 92.2ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 2 trucks, 84.5ms
# Speed: 1.3ms preprocess, 84.5ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 10 cars, 2 trucks, 84.3ms
# Speed: 1.2ms preprocess, 84.3ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 2 trucks, 104.0ms
# Speed: 1.4ms preprocess, 104.0ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 10 cars, 2 trucks,
4ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 7 cars, 2 trucks, 127.1ms
# Speed: 1.4ms preprocess, 127.1ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 8 cars, 3 trucks, 96.8ms
# Speed: 1.3ms preprocess, 96.8ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 8 cars, 3 trucks, 102.8ms
# Speed: 1.3ms preprocess, 102.8ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 8 cars, 2 trucks, 91.1ms
# Speed: 1.2ms preprocess, 91.1ms inference, 0.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 4 trucks, 97.3ms
# Speed: 1.5ms preprocess, 97.3ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 8 cars, 4 trucks, 95.2ms
# Speed: 1.4ms preprocess, 95.2ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 2 trucks, 94.6ms
# Speed: 1.6ms preprocess, 94.6ms inference, 0.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 2 trucks, 108.6ms
# Speed: 1.3ms preprocess, 108.6ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 2 trucks, 100.2ms
# Speed: 1.7ms preprocess, 100.2ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 2 trucks, 99.5ms
# Speed: 1.5ms preprocess, 99.5ms inference, 0.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 10 cars, 2 trucks, 95.7ms
# Speed: 1.4ms preprocess, 95.7ms inference, 0.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 2 trucks, 90.6ms
# Speed: 1.7ms preprocess, 90.6ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 8 cars, 2 trucks, 81.3ms
# Speed: 1.3ms preprocess, 81.3ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 8 cars, 2 trucks, 105.5ms
# Speed: 1.7ms preprocess, 105.5ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 8 cars, 2 trucks, 75.4ms
# Speed: 1.5ms preprocess, 75.4ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 1 truck, 85.2ms
# Speed: 2.0ms preprocess, 85.2ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 8 cars, 1 truck, 96.9ms
# Speed: 1.5ms preprocess, 96.9ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 1 truck, 120.6ms
# Speed: 1.6ms preprocess, 120.6ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 8 cars, 2 trucks, 116.9ms
# Speed: 1.5ms preprocess, 116.9ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 1 truck, 81.7ms
# Speed: 1.5ms preprocess, 81.7ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 1 truck, 91.7ms
# Speed: 1.3ms preprocess, 91.7ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 8 cars, 1 truck, 86.0ms
# Speed: 1.5ms preprocess, 86.0ms inference, 0.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 8 cars, 1 truck, 89.9ms
# Speed: 1.6ms preprocess, 89.9ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 8 cars, 1 truck, 86.8ms
# Speed: 1.5ms preprocess, 86.8ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 1 truck, 87.6ms
# Speed: 1.5ms preprocess, 87.6ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 1 truck, 90.5ms
# Speed: 1.2ms preprocess, 90.5ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 1 truck, 100.1ms
# Speed: 1.1ms preprocess, 100.1ms inference, 0.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 10 cars, 1 truck, 104.2ms
# Speed: 1.3ms preprocess, 104.2ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 11 cars, 1 truck, 99.5ms
# Speed: 1.3ms preprocess, 99.5ms inference, 0.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 1 truck, 97.3ms
# Speed: 1.3ms preprocess, 97.3ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 10 cars, 1 truck, 89.8ms
# Speed: 1.2ms preprocess, 89.8ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 10 cars, 1 truck, 90.2ms
# Speed: 1.3ms preprocess, 90.2ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 10 cars, 1 truck, 84.9ms
# Speed: 1.3ms preprocess, 84.9ms inference, 0.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 10 cars, 1 truck, 90.8ms
# Speed: 1.2ms preprocess, 90.8ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 1 truck, 90.7ms
# Speed: 1.3ms preprocess, 90.7ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 1 truck, 102.2ms
# Speed: 1.3ms preprocess, 102.2ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 1 truck, 93.0ms
# Speed: 1.3ms preprocess, 93.0ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 1 truck, 94.2ms
# Speed: 1.2ms preprocess, 94.2ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 1 truck, 86.5ms
# Speed: 1.4ms preprocess, 86.5ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 2 trucks, 99.2ms
# Speed: 1.4ms preprocess, 99.2ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 8 cars, 1 truck, 85.9ms
# Speed: 1.3ms preprocess, 85.9ms inference, 0.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 8 cars, 1 truck, 80.6ms
# Speed: 1.3ms preprocess, 80.6ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 8 cars, 1 truck, 89.5ms
# Speed: 1.5ms preprocess, 89.5ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 8 cars, 1 truck, 105.7ms
# Speed: 1.6ms preprocess, 105.7ms inference, 0.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 8 cars, 2 trucks, 104.9ms
# Speed: 1.4ms preprocess, 104.9ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 7 cars, 1 truck, 89.0ms
# Speed: 1.5ms preprocess, 89.0ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 7 cars, 1 truck, 90.0ms
# Speed: 1.5ms preprocess, 90.0ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 8 cars, 1 truck, 100.8ms
# Speed: 1.6ms preprocess, 100.8ms inference, 0.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 8 cars, 1 truck, 95.5ms
# Speed: 1.7ms preprocess, 95.5ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 8 cars, 1 truck, 91.8ms
# Speed: 1.4ms preprocess, 91.8ms inference, 0.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 8 cars, 1 truck, 83.4ms
# Speed: 1.6ms preprocess, 83.4ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 8 cars, 1 truck, 90.9ms
# Speed: 1.3ms preprocess, 90.9ms inference, 0.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 8 cars, 2 trucks, 116.3ms
# Speed: 1.2ms preprocess, 116.3ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 1 truck, 87.4ms
# Speed: 1.5ms preprocess, 87.4ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 1 truck, 93.2ms
# Speed: 1.4ms preprocess, 93.2ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 10 cars, 1 truck, 98.2ms
# Speed: 1.3ms preprocess, 98.2ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 10 cars, 1 truck, 106.6ms
# Speed: 1.6ms preprocess, 106.6ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 10 cars, 1 truck, 119.3ms
# Speed: 1.8ms preprocess, 119.3ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 11 cars, 2 trucks, 94.2ms
# Speed: 1.6ms preprocess, 94.2ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
# Vehicles going down: 8
# Vehicles going up: 3
# Total vehicles: 11
# Output video saved to: output.avi
# Tracking data has been saved to 'tracking_data.pkl'
